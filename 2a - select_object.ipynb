# %% [markdown]
# 2a - A imagem RGB airport.png apresenta uma pista de aeroporto, conforme indicado abaixo. Implemente um código responsável pela seleção dos conjuntos de pixels associados ao objeto silo

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img_airport_bgr = cv2.imread('../ex2/airport.PNG')

img_hsv = cv2.cvtColor(img_airport_bgr, cv2.COLOR_BGR2HSV)
img_airport = cv2.cvtColor(img_airport_bgr, cv2.COLOR_BGR2RGB)

# %%
lower_white = np.array([0, 0, 200], dtype=np.uint8)
upper_white = np.array([180, 50, 255], dtype=np.uint8)

mask = cv2.inRange(img_hsv, lower_white, upper_white)

contornos, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

img_contornos = img_airport.copy()
cv2.drawContours(img_contornos, contornos, -1, (255, 0, 0), 2)
# Out:
# array([[[122, 102,  87],
#         [122, 102,  87],
#         [120,  99,  82],
#         ...,
#         [ 51,  61,  50],
#         [ 53,  62,  48],
#         [ 56,  61,  50]],
#
#        [[115,  97,  85],
#         [115,  97,  85],
#         [113,  96,  82],
#         ...,
#         [ 50,  58,  50],
#         [ 51,  62,  51],
#         [ 53,  65,  51]],
#
#        [[115,  97,  85],
#         [115,  97,  85],
#         [113,  96,  82],
#         ...,
#         [ 50,  58,  50],
#         [ 51,  62,  51],
#         [ 53,  65,  51]],
#
#        ...,
#
#        [[ 56,  65,  55],
#         [ 56,  65,  55],
#         [ 55,  61,  53],
#         ...,
#         [105,  95,  75],
#         [105,  95,  77],
#         [105,  95,  78]],
#
#        [[ 58,  64,  53],
#         [ 58,  64,  53],
#         [ 58,  62,  50],
#         ...,
#         [104,  95,  78],
#         [105,  95,  81],
#         [105, 101,  78]],
#
#        [[ 56,  62,  55],
#         [ 56,  62,  55],
#         [ 55,  61,  56],
# ...

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.imshow(img_contornos)
plt.title('Imagem Original com Contornos')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(mask, cmap='gray')
plt.title('Máscara de Segmentação')
plt.axis('off')

plt.show()
